# %% [markdown]
# # Collecting data

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

#Import the data set

titanic_data = pd.read_csv('C:\\Users\\pc\\Desktop\\datasets\\datasets\\titanic.csv')

# %% [markdown]
#  ## analyzing Data

# %%
sns.countplot(x='Survived', data=titanic_data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived', hue='Sex', data=titanic_data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived', hue='Pclass', data=titanic_data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.hist(titanic_data['Fare'])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(titanic_data['Pclass'], titanic_data['Age'])
# Out:
# C:\Users\pc\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
#  ### Data Wrangling Process is not shown as it was already done before

# %% [markdown]
# ## Train and Test

# %%
y_data = titanic_data['Survived']

x_data = titanic_data.drop('Survived', axis = 1)

#Split the data set into training data and test data

from sklearn.model_selection import train_test_split

x_training_data, x_test_data, y_training_data, y_test_data = train_test_split(x_data, y_data, test_size = 0.3)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

#Train the model and create predictions

model.fit(x_training_data, y_training_data)

predictions = model.predict(x_test_data)

#Calculate performance metrics

from sklearn.metrics import classification_report

print(classification_report(y_test_data, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.87      0.78       128
#            1       0.70      0.47      0.56        86
#
#     accuracy                           0.71       214
#    macro avg       0.70      0.67      0.67       214
# weighted avg       0.70      0.71      0.69       214

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test_data, predictions))
# Out:
# [[111  17]
#  [ 46  40]]

# %% [markdown]
# ## Accuracy Check

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test_data,predictions)
# Out:
# 0.705607476635514
