# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import seaborn as sns # visualization tool

# %%
data=pd.read_csv('C:\\Users\\pc\\Desktop\\datasets\\Data-Science-Datasets\\pokemon.csv')

# %%
data.head(5)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
data.corr() # data correlation works like if the data is positively correlated then the x will be increased as respect to the 
#y and if it is negative then increase in x will lead to a decrease in y. for ex : if against-electric increases then against_bug
#and others decreases.
# Out:
#                    against_bug  against_dark  against_dragon  \
# against_bug           1.000000      0.230107        0.165430
# against_dark          0.230107      1.000000        0.140830
# against_dragon        0.165430      0.140830        1.000000
# against_electric     -0.246943     -0.015830       -0.108928
# against_fairy         0.239566     -0.301354        0.439705
# against_fight         0.137902     -0.357981        0.035237
# against_fire          0.202778      0.010527       -0.261570
# against_flying        0.183343     -0.179697        0.064850
# against_ghost         0.129174      0.672337       -0.049941
# against_grass         0.079197     -0.006533       -0.037135
# against_ground       -0.186841     -0.007660       -0.120042
# against_ice           0.148176     -0.010763        0.350048
# against_normal        0.215589     -0.413632        0.142035
# against_poison        0.354255     -0.236919       -0.210199
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
#line plot
data.speed.plot(kind='line',color='g',label='speed',linewidth='5',linestyle=':')
data.defense.plot(kind='line',color='r',label='defense',linewidth='1',linestyle='-')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
#Scatter Plot
data.plot(kind='scatter',x='attack',y='defense')
# Out:
# <AxesSubplot:xlabel='attack', ylabel='defense'>

# %%
#Histogram
#bins=number of bar in fig.
data.speed.plot(kind='hist',bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 1 - Filtering Pandas data Frame
x=data['attack']>170
data[x]
# Out:
#                       abilities  against_bug  against_dark  against_dragon  \
# 213  ['Swarm', 'Guts', 'Moxie']          0.5           0.5             1.0
# 382                 ['Drought']          1.0           1.0             1.0
# 383                ['Air Lock']          0.5           1.0             2.0
# 797             ['Beast Boost']          1.0           1.0             0.5
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 213               1.0            2.0            0.5           2.0
# 382               0.0            1.0            1.0           1.0
# 383               1.0            2.0            0.5           0.5
# 797               0.5            0.5            2.0           4.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 213             4.0            1.0  ...             50.0             214
# 382             1.0            1.0  ...              NaN             383
# ...

# %%
# 2 - Filtering pandas with logical '&' 
data[(data['defense']>200) & (data['attack'])]
# Out:
#                                   abilities  against_bug  against_dark  \
# 207  ['Rock Head', 'Sturdy', 'Sheer Force']          0.5           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 207             0.5               0.0            0.5            2.0
#
#      against_fire  against_flying  against_ghost  ...  percentage_male  \
# 207           2.0             0.5            1.0  ...             50.0
#
#      pokedex_number  sp_attack  sp_defense  speed  type1   type2  weight_kg  \
# 207             208         55          95     30  steel  ground      400.0
#
#      generation  is_legendary
# 207           2             0
#
# [1 rows x 41 columns]

# %%
#scope 
a=10; #global Scope
def fun():
    b=12; #local scope

# %%
#built in Scope 
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %% [markdown]
# ### Data Exploratory

# %%
# to count a specific column Just use value_counts()
print(data['is_legendary'].value_counts(dropna=False))
# Out:
# 0    731
# 1     70
# Name: is_legendary, dtype: int64

# %%
data.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %% [markdown]
# ### Visual Exploratory

# %%
data.boxplot(column='attack',by='defense')
# Out:
# <AxesSubplot:title={'center':'attack'}, xlabel='defense'>
